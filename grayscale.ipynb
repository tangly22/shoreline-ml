# %%
# !pip install opencv-python
#pip install libgl1-mesa-glx
# Out:
# Requirement already satisfied: opencv-python in /Users/emilytango-lee/anaconda3/lib/python3.11/site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in /Users/emilytango-lee/anaconda3/lib/python3.11/site-packages (from opencv-python) (1.24.3)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
 
img = cv.imread('oakisland_west-test.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.axis('off')  # Turn off axis labels
plt.show()
